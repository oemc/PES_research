# %%
import requests

indicators = ['RL.NO.SRC',
'RL.PER.RNK',
'RL.PER.RNK.LOWER',
'RL.PER.RNK.UPPER',
'RL.STD.ERR',
'VA.EST',
'VA.NO.SRC',
'VA.PER.RNK',
'VA.PER.RNK.LOWER',
'VA.PER.RNK.UPPER',
'VA.STD.ERR'
]
for indicator in indicators:
    rows = []
    #indicator = 'CC.EST'
    countries = 'AF;AO;BI;BJ;BF;BD;BO;BT;CF;CI;CM;CD;CG;KM;CV;DJ;EG;ER;ET;FM;GH;GN;GM;GW;HN;HT;IN;JO;KE;KG;KH;KI;LA;LB;LR;LK;LS;MA;MG;ML;MM;MZ;MR;MW;NE;NG;NI;NP;PK;PH;PG;KP;PS;RW;SD;SN;SB;SL;SO;SS;ST;SZ;SY;TD;TG;TJ;TL;TN;TZ;UG;UZ;VN;VU;WS;YE;ZM;ZW'
    url = f'https://api.worldbank.org/v2/en/country/{countries}/indicator/{indicator}?format=json&date=1995:2023&per_page=50'

    response = requests.get(url)

    if response.status_code == 200:  # Verifica que la solicitud fue exitosa
        data = response.json()       # Convierte la respuesta JSON a un diccionario de Python
        print(data[0])
    else:
        print(f"Error {response.status_code}: No se pudo obtener los datos.")



    for i in range(2, data[0]['pages'] + 1):
        for row in data[1]:
            rows.append(f"{row['indicator']['id']},{row['country']['id']},{row['date']},{row['value']}")
        
        print(f'Se hace request GET {i} para el indicador {indicator}')
        
        response = requests.get(f'{url}&page={i}')
        if response.status_code == 200:  # Verifica que la solicitud fue exitosa
            data = response.json()       # Convierte la respuesta JSON a un diccionario de Python
        else:
            print(f"Error {response.status_code}: No se pudo obtener los datos.")
            break

    # Abrir un archivo en modo escritura
    with open(f"datos_python{indicator.replace('.','_')}.csv", 'w') as file:
        for item in rows:
            file.write(f"{item}\n")  # Escribir cada elemento en una nueva línea
# Out:
# {'page': 1, 'pages': 45, 'per_page': 50, 'total': 2233, 'sourceid': '2', 'lastupdated': '2024-06-28'}
# Se hace request GET 2 para el indicador RL.NO.SRC
# Se hace request GET 3 para el indicador RL.NO.SRC
# Se hace request GET 4 para el indicador RL.NO.SRC
# Se hace request GET 5 para el indicador RL.NO.SRC
# Se hace request GET 6 para el indicador RL.NO.SRC
# Se hace request GET 7 para el indicador RL.NO.SRC
# Se hace request GET 8 para el indicador RL.NO.SRC
# Se hace request GET 9 para el indicador RL.NO.SRC
# Se hace request GET 10 para el indicador RL.NO.SRC
# Se hace request GET 11 para el indicador RL.NO.SRC
# Se hace request GET 12 para el indicador RL.NO.SRC
# Se hace request GET 13 para el indicador RL.NO.SRC
# Se hace request GET 14 para el indicador RL.NO.SRC
# Se hace request GET 15 para el indicador RL.NO.SRC
# Se hace request GET 16 para el indicador RL.NO.SRC
# Se hace request GET 17 para el indicador RL.NO.SRC
# Se hace request GET 18 para el indicador RL.NO.SRC
# Se hace request GET 19 para el indicador RL.NO.SRC
# Se hace request GET 20 para el indicador RL.NO.SRC
# Se hace request GET 21 para el indicador RL.NO.SRC
# Se hace request GET 22 para el indicador RL.NO.SRC
# Se hace request GET 23 para el indicador RL.NO.SRC
# Se hace request GET 24 para el indicador RL.NO.SRC
# Se hace request GET 25 para el indicador RL.NO.SRC
# Se hace request GET 26 para el indicador RL.NO.SRC
# Se hace request GET 27 para el indicador RL.NO.SRC
# Se hace request GET 28 para el indicador RL.NO.SRC
# Se hace request GET 29 para el indicador RL.NO.SRC
# Se hace request GET 30 para el indicador RL.NO.SRC
# Se hace request GET 31 para el indicador RL.NO.SRC
# Se hace request GET 32 para el indicador RL.NO.SRC
# Se hace request GET 33 para el indicador RL.NO.SRC
# Se hace request GET 34 para el indicador RL.NO.SRC
# Se hace request GET 35 para el indicador RL.NO.SRC
# Se hace request GET 36 para el indicador RL.NO.SRC
# Se hace request GET 37 para el indicador RL.NO.SRC
# Se hace request GET 38 para el indicador RL.NO.SRC
# Se hace request GET 39 para el indicador RL.NO.SRC
# Se hace request GET 40 para el indicador RL.NO.SRC
# Se hace request GET 41 para el indicador RL.NO.SRC
# Se hace request GET 42 para el indicador RL.NO.SRC
# Se hace request GET 43 para el indicador RL.NO.SRC
# Se hace request GET 44 para el indicador RL.NO.SRC
# Se hace request GET 45 para el indicador RL.NO.SRC
# {'page': 1, 'pages': 45, 'per_page': 50, 'total': 2233, 'sourceid': '2', 'lastupdated': '2024-06-28'}
# Se hace request GET 2 para el indicador RL.PER.RNK
# Se hace request GET 3 para el indicador RL.PER.RNK
# Se hace request GET 4 para el indicador RL.PER.RNK
# Se hace request GET 5 para el indicador RL.PER.RNK
# Se hace request GET 6 para el indicador RL.PER.RNK
# Se hace request GET 7 para el indicador RL.PER.RNK
# Se hace request GET 8 para el indicador RL.PER.RNK
# Se hace request GET 9 para el indicador RL.PER.RNK
# Se hace request GET 10 para el indicador RL.PER.RNK
# Se hace request GET 11 para el indicador RL.PER.RNK
# Se hace request GET 12 para el indicador RL.PER.RNK
# Se hace request GET 13 para el indicador RL.PER.RNK
# Se hace request GET 14 para el indicador RL.PER.RNK
# Se hace request GET 15 para el indicador RL.PER.RNK
# Se hace request GET 16 para el indicador RL.PER.RNK
# Se hace request GET 17 para el indicador RL.PER.RNK
# Se hace request GET 18 para el indicador RL.PER.RNK
# Se hace request GET 19 para el indicador RL.PER.RNK
# Se hace request GET 20 para el indicador RL.PER.RNK
# Se hace request GET 21 para el indicador RL.PER.RNK
# Se hace request GET 22 para el indicador RL.PER.RNK
# Se hace request GET 23 para el indicador RL.PER.RNK
# Se hace request GET 24 para el indicador RL.PER.RNK
# Se hace request GET 25 para el indicador RL.PER.RNK
# Se hace request GET 26 para el indicador RL.PER.RNK
# Se hace request GET 27 para el indicador RL.PER.RNK
# Se hace request GET 28 para el indicador RL.PER.RNK
# Se hace request GET 29 para el indicador RL.PER.RNK
# Se hace request GET 30 para el indicador RL.PER.RNK
# Se hace request GET 31 para el indicador RL.PER.RNK
# Se hace request GET 32 para el indicador RL.PER.RNK
# Se hace request GET 33 para el indicador RL.PER.RNK
# Se hace request GET 34 para el indicador RL.PER.RNK
# Se hace request GET 35 para el indicador RL.PER.RNK
# Se hace request GET 36 para el indicador RL.PER.RNK
# Se hace request GET 37 para el indicador RL.PER.RNK
# Se hace request GET 38 para el indicador RL.PER.RNK
# Se hace request GET 39 para el indicador RL.PER.RNK
# Se hace request GET 40 para el indicador RL.PER.RNK
# Se hace request GET 41 para el indicador RL.PER.RNK
# Se hace request GET 42 para el indicador RL.PER.RNK
# Se hace request GET 43 para el indicador RL.PER.RNK
# Se hace request GET 44 para el indicador RL.PER.RNK
# Se hace request GET 45 para el indicador RL.PER.RNK
# {'page': 1, 'pages': 45, 'per_page': 50, 'total': 2233, 'sourceid': '2', 'lastupdated': '2024-06-28'}
# Se hace request GET 2 para el indicador RL.PER.RNK.LOWER
# Se hace request GET 3 para el indicador RL.PER.RNK.LOWER
# Se hace request GET 4 para el indicador RL.PER.RNK.LOWER
# Se hace request GET 5 para el indicador RL.PER.RNK.LOWER
# Se hace request GET 6 para el indicador RL.PER.RNK.LOWER
# Se hace request GET 7 para el indicador RL.PER.RNK.LOWER
# Se hace request GET 8 para el indicador RL.PER.RNK.LOWER
# Se hace request GET 9 para el indicador RL.PER.RNK.LOWER
# Se hace request GET 10 para el indicador RL.PER.RNK.LOWER
# Se hace request GET 11 para el indicador RL.PER.RNK.LOWER
# Se hace request GET 12 para el indicador RL.PER.RNK.LOWER
# Se hace request GET 13 para el indicador RL.PER.RNK.LOWER
# Se hace request GET 14 para el indicador RL.PER.RNK.LOWER
# Se hace request GET 15 para el indicador RL.PER.RNK.LOWER
# Se hace request GET 16 para el indicador RL.PER.RNK.LOWER
# Se hace request GET 17 para el indicador RL.PER.RNK.LOWER
# Se hace request GET 18 para el indicador RL.PER.RNK.LOWER
# Se hace request GET 19 para el indicador RL.PER.RNK.LOWER
# Se hace request GET 20 para el indicador RL.PER.RNK.LOWER
# Se hace request GET 21 para el indicador RL.PER.RNK.LOWER
# Se hace request GET 22 para el indicador RL.PER.RNK.LOWER
# Se hace request GET 23 para el indicador RL.PER.RNK.LOWER
# Se hace request GET 24 para el indicador RL.PER.RNK.LOWER
# Se hace request GET 25 para el indicador RL.PER.RNK.LOWER
# Se hace request GET 26 para el indicador RL.PER.RNK.LOWER
# Se hace request GET 27 para el indicador RL.PER.RNK.LOWER
# Se hace request GET 28 para el indicador RL.PER.RNK.LOWER
# Se hace request GET 29 para el indicador RL.PER.RNK.LOWER
# Se hace request GET 30 para el indicador RL.PER.RNK.LOWER
# Se hace request GET 31 para el indicador RL.PER.RNK.LOWER
# Se hace request GET 32 para el indicador RL.PER.RNK.LOWER
# Se hace request GET 33 para el indicador RL.PER.RNK.LOWER
# Se hace request GET 34 para el indicador RL.PER.RNK.LOWER
# Se hace request GET 35 para el indicador RL.PER.RNK.LOWER
# Se hace request GET 36 para el indicador RL.PER.RNK.LOWER
# Se hace request GET 37 para el indicador RL.PER.RNK.LOWER
# Se hace request GET 38 para el indicador RL.PER.RNK.LOWER
# Se hace request GET 39 para el indicador RL.PER.RNK.LOWER
# Se hace request GET 40 para el indicador RL.PER.RNK.LOWER
# Se hace request GET 41 para el indicador RL.PER.RNK.LOWER
# Se hace request GET 42 para el indicador RL.PER.RNK.LOWER
# Se hace request GET 43 para el indicador RL.PER.RNK.LOWER
# Se hace request GET 44 para el indicador RL.PER.RNK.LOWER
# Se hace request GET 45 para el indicador RL.PER.RNK.LOWER
# {'page': 1, 'pages': 45, 'per_page': 50, 'total': 2233, 'sourceid': '2', 'lastupdated': '2024-06-28'}
# Se hace request GET 2 para el indicador RL.PER.RNK.UPPER
# Se hace request GET 3 para el indicador RL.PER.RNK.UPPER
# Se hace request GET 4 para el indicador RL.PER.RNK.UPPER
# Se hace request GET 5 para el indicador RL.PER.RNK.UPPER
# Se hace request GET 6 para el indicador RL.PER.RNK.UPPER
# Se hace request GET 7 para el indicador RL.PER.RNK.UPPER
# Se hace request GET 8 para el indicador RL.PER.RNK.UPPER
# Se hace request GET 9 para el indicador RL.PER.RNK.UPPER
# Se hace request GET 10 para el indicador RL.PER.RNK.UPPER
# Se hace request GET 11 para el indicador RL.PER.RNK.UPPER
# Se hace request GET 12 para el indicador RL.PER.RNK.UPPER
# Se hace request GET 13 para el indicador RL.PER.RNK.UPPER
# Se hace request GET 14 para el indicador RL.PER.RNK.UPPER
# Se hace request GET 15 para el indicador RL.PER.RNK.UPPER
# Se hace request GET 16 para el indicador RL.PER.RNK.UPPER
# Se hace request GET 17 para el indicador RL.PER.RNK.UPPER
# Se hace request GET 18 para el indicador RL.PER.RNK.UPPER
# Se hace request GET 19 para el indicador RL.PER.RNK.UPPER
# Se hace request GET 20 para el indicador RL.PER.RNK.UPPER
# Se hace request GET 21 para el indicador RL.PER.RNK.UPPER
# Se hace request GET 22 para el indicador RL.PER.RNK.UPPER
# Se hace request GET 23 para el indicador RL.PER.RNK.UPPER
# Se hace request GET 24 para el indicador RL.PER.RNK.UPPER
# Se hace request GET 25 para el indicador RL.PER.RNK.UPPER
# Se hace request GET 26 para el indicador RL.PER.RNK.UPPER
# Se hace request GET 27 para el indicador RL.PER.RNK.UPPER
# Se hace request GET 28 para el indicador RL.PER.RNK.UPPER
# Se hace request GET 29 para el indicador RL.PER.RNK.UPPER
# Se hace request GET 30 para el indicador RL.PER.RNK.UPPER
# Se hace request GET 31 para el indicador RL.PER.RNK.UPPER
# Se hace request GET 32 para el indicador RL.PER.RNK.UPPER
# Se hace request GET 33 para el indicador RL.PER.RNK.UPPER
# Se hace request GET 34 para el indicador RL.PER.RNK.UPPER
# Se hace request GET 35 para el indicador RL.PER.RNK.UPPER
# Se hace request GET 36 para el indicador RL.PER.RNK.UPPER
# Se hace request GET 37 para el indicador RL.PER.RNK.UPPER
# Se hace request GET 38 para el indicador RL.PER.RNK.UPPER
# Se hace request GET 39 para el indicador RL.PER.RNK.UPPER
# Se hace request GET 40 para el indicador RL.PER.RNK.UPPER
# Se hace request GET 41 para el indicador RL.PER.RNK.UPPER
# Se hace request GET 42 para el indicador RL.PER.RNK.UPPER
# Se hace request GET 43 para el indicador RL.PER.RNK.UPPER
# Se hace request GET 44 para el indicador RL.PER.RNK.UPPER
# Se hace request GET 45 para el indicador RL.PER.RNK.UPPER
# {'page': 1, 'pages': 45, 'per_page': 50, 'total': 2233, 'sourceid': '2', 'lastupdated': '2024-06-28'}
# Se hace request GET 2 para el indicador RL.STD.ERR
# Se hace request GET 3 para el indicador RL.STD.ERR
# Se hace request GET 4 para el indicador RL.STD.ERR
# Se hace request GET 5 para el indicador RL.STD.ERR
# Se hace request GET 6 para el indicador RL.STD.ERR
# Se hace request GET 7 para el indicador RL.STD.ERR
# Se hace request GET 8 para el indicador RL.STD.ERR
# Se hace request GET 9 para el indicador RL.STD.ERR
# Se hace request GET 10 para el indicador RL.STD.ERR
# Se hace request GET 11 para el indicador RL.STD.ERR
# Se hace request GET 12 para el indicador RL.STD.ERR
# Se hace request GET 13 para el indicador RL.STD.ERR
# Se hace request GET 14 para el indicador RL.STD.ERR
# Se hace request GET 15 para el indicador RL.STD.ERR
# Se hace request GET 16 para el indicador RL.STD.ERR
# Se hace request GET 17 para el indicador RL.STD.ERR
# Se hace request GET 18 para el indicador RL.STD.ERR
# Se hace request GET 19 para el indicador RL.STD.ERR
# Se hace request GET 20 para el indicador RL.STD.ERR
# Se hace request GET 21 para el indicador RL.STD.ERR
# Se hace request GET 22 para el indicador RL.STD.ERR
# Se hace request GET 23 para el indicador RL.STD.ERR
# Se hace request GET 24 para el indicador RL.STD.ERR
# Se hace request GET 25 para el indicador RL.STD.ERR
# Se hace request GET 26 para el indicador RL.STD.ERR
# Se hace request GET 27 para el indicador RL.STD.ERR
# Se hace request GET 28 para el indicador RL.STD.ERR
# Se hace request GET 29 para el indicador RL.STD.ERR
# Se hace request GET 30 para el indicador RL.STD.ERR
# Se hace request GET 31 para el indicador RL.STD.ERR
# Se hace request GET 32 para el indicador RL.STD.ERR
# Se hace request GET 33 para el indicador RL.STD.ERR
# Se hace request GET 34 para el indicador RL.STD.ERR
# Se hace request GET 35 para el indicador RL.STD.ERR
# Se hace request GET 36 para el indicador RL.STD.ERR
# Se hace request GET 37 para el indicador RL.STD.ERR
# Se hace request GET 38 para el indicador RL.STD.ERR
# Se hace request GET 39 para el indicador RL.STD.ERR
# Se hace request GET 40 para el indicador RL.STD.ERR
# Se hace request GET 41 para el indicador RL.STD.ERR
# Se hace request GET 42 para el indicador RL.STD.ERR
# Se hace request GET 43 para el indicador RL.STD.ERR
# Se hace request GET 44 para el indicador RL.STD.ERR
# Se hace request GET 45 para el indicador RL.STD.ERR
# {'page': 1, 'pages': 45, 'per_page': 50, 'total': 2233, 'sourceid': '2', 'lastupdated': '2024-06-28'}
# Se hace request GET 2 para el indicador VA.EST
# Se hace request GET 3 para el indicador VA.EST
# Se hace request GET 4 para el indicador VA.EST
# Se hace request GET 5 para el indicador VA.EST
# Se hace request GET 6 para el indicador VA.EST
# Se hace request GET 7 para el indicador VA.EST
# Se hace request GET 8 para el indicador VA.EST
# Se hace request GET 9 para el indicador VA.EST
# Se hace request GET 10 para el indicador VA.EST
# Se hace request GET 11 para el indicador VA.EST
# Se hace request GET 12 para el indicador VA.EST
# Se hace request GET 13 para el indicador VA.EST
# Se hace request GET 14 para el indicador VA.EST
# Se hace request GET 15 para el indicador VA.EST
# Se hace request GET 16 para el indicador VA.EST
# Se hace request GET 17 para el indicador VA.EST
# Se hace request GET 18 para el indicador VA.EST
# Se hace request GET 19 para el indicador VA.EST
# Se hace request GET 20 para el indicador VA.EST
# Se hace request GET 21 para el indicador VA.EST
# Se hace request GET 22 para el indicador VA.EST
# Se hace request GET 23 para el indicador VA.EST
# Se hace request GET 24 para el indicador VA.EST
# Se hace request GET 25 para el indicador VA.EST
# Se hace request GET 26 para el indicador VA.EST
# Se hace request GET 27 para el indicador VA.EST
# Se hace request GET 28 para el indicador VA.EST
# Se hace request GET 29 para el indicador VA.EST
# Se hace request GET 30 para el indicador VA.EST
# Se hace request GET 31 para el indicador VA.EST
# Se hace request GET 32 para el indicador VA.EST
# Se hace request GET 33 para el indicador VA.EST
# Se hace request GET 34 para el indicador VA.EST
# Se hace request GET 35 para el indicador VA.EST
# Se hace request GET 36 para el indicador VA.EST
# Se hace request GET 37 para el indicador VA.EST
# Se hace request GET 38 para el indicador VA.EST
# Se hace request GET 39 para el indicador VA.EST
# Se hace request GET 40 para el indicador VA.EST
# Se hace request GET 41 para el indicador VA.EST
# Se hace request GET 42 para el indicador VA.EST
# Se hace request GET 43 para el indicador VA.EST
# Se hace request GET 44 para el indicador VA.EST
# Se hace request GET 45 para el indicador VA.EST
# {'page': 1, 'pages': 45, 'per_page': 50, 'total': 2233, 'sourceid': '2', 'lastupdated': '2024-06-28'}
# Se hace request GET 2 para el indicador VA.NO.SRC
# Se hace request GET 3 para el indicador VA.NO.SRC
# Se hace request GET 4 para el indicador VA.NO.SRC
# Se hace request GET 5 para el indicador VA.NO.SRC
# Se hace request GET 6 para el indicador VA.NO.SRC
# Se hace request GET 7 para el indicador VA.NO.SRC
# Se hace request GET 8 para el indicador VA.NO.SRC
# Se hace request GET 9 para el indicador VA.NO.SRC
# Se hace request GET 10 para el indicador VA.NO.SRC
# Se hace request GET 11 para el indicador VA.NO.SRC
# Se hace request GET 12 para el indicador VA.NO.SRC
# Se hace request GET 13 para el indicador VA.NO.SRC
# Se hace request GET 14 para el indicador VA.NO.SRC
# Se hace request GET 15 para el indicador VA.NO.SRC
# Se hace request GET 16 para el indicador VA.NO.SRC
# Se hace request GET 17 para el indicador VA.NO.SRC
# Se hace request GET 18 para el indicador VA.NO.SRC
# Se hace request GET 19 para el indicador VA.NO.SRC
# Se hace request GET 20 para el indicador VA.NO.SRC
# Se hace request GET 21 para el indicador VA.NO.SRC
# Se hace request GET 22 para el indicador VA.NO.SRC
# Se hace request GET 23 para el indicador VA.NO.SRC
# Se hace request GET 24 para el indicador VA.NO.SRC
# Se hace request GET 25 para el indicador VA.NO.SRC
# Se hace request GET 26 para el indicador VA.NO.SRC
# Se hace request GET 27 para el indicador VA.NO.SRC
# Se hace request GET 28 para el indicador VA.NO.SRC
# Se hace request GET 29 para el indicador VA.NO.SRC
# Se hace request GET 30 para el indicador VA.NO.SRC
# Se hace request GET 31 para el indicador VA.NO.SRC
# Se hace request GET 32 para el indicador VA.NO.SRC
# Se hace request GET 33 para el indicador VA.NO.SRC
# Se hace request GET 34 para el indicador VA.NO.SRC
# Se hace request GET 35 para el indicador VA.NO.SRC
# Se hace request GET 36 para el indicador VA.NO.SRC
# Se hace request GET 37 para el indicador VA.NO.SRC
# Se hace request GET 38 para el indicador VA.NO.SRC
# Se hace request GET 39 para el indicador VA.NO.SRC
# Se hace request GET 40 para el indicador VA.NO.SRC
# Se hace request GET 41 para el indicador VA.NO.SRC
# Se hace request GET 42 para el indicador VA.NO.SRC
# Se hace request GET 43 para el indicador VA.NO.SRC
# Se hace request GET 44 para el indicador VA.NO.SRC
# Se hace request GET 45 para el indicador VA.NO.SRC
# {'page': 1, 'pages': 45, 'per_page': 50, 'total': 2233, 'sourceid': '2', 'lastupdated': '2024-06-28'}
# Se hace request GET 2 para el indicador VA.PER.RNK
# Se hace request GET 3 para el indicador VA.PER.RNK
# Se hace request GET 4 para el indicador VA.PER.RNK
# Se hace request GET 5 para el indicador VA.PER.RNK
# Se hace request GET 6 para el indicador VA.PER.RNK
# Se hace request GET 7 para el indicador VA.PER.RNK
# Se hace request GET 8 para el indicador VA.PER.RNK
# Se hace request GET 9 para el indicador VA.PER.RNK
# Se hace request GET 10 para el indicador VA.PER.RNK
# Se hace request GET 11 para el indicador VA.PER.RNK
# Se hace request GET 12 para el indicador VA.PER.RNK
# Se hace request GET 13 para el indicador VA.PER.RNK
# Se hace request GET 14 para el indicador VA.PER.RNK
# Se hace request GET 15 para el indicador VA.PER.RNK
# Se hace request GET 16 para el indicador VA.PER.RNK
# Se hace request GET 17 para el indicador VA.PER.RNK
# Se hace request GET 18 para el indicador VA.PER.RNK
# Se hace request GET 19 para el indicador VA.PER.RNK
# Se hace request GET 20 para el indicador VA.PER.RNK
# Se hace request GET 21 para el indicador VA.PER.RNK
# Se hace request GET 22 para el indicador VA.PER.RNK
# Se hace request GET 23 para el indicador VA.PER.RNK
# Se hace request GET 24 para el indicador VA.PER.RNK
# Se hace request GET 25 para el indicador VA.PER.RNK
# Se hace request GET 26 para el indicador VA.PER.RNK
# Se hace request GET 27 para el indicador VA.PER.RNK
# Se hace request GET 28 para el indicador VA.PER.RNK
# Se hace request GET 29 para el indicador VA.PER.RNK
# Se hace request GET 30 para el indicador VA.PER.RNK
# Se hace request GET 31 para el indicador VA.PER.RNK
# Se hace request GET 32 para el indicador VA.PER.RNK
# Se hace request GET 33 para el indicador VA.PER.RNK
# Se hace request GET 34 para el indicador VA.PER.RNK
# Se hace request GET 35 para el indicador VA.PER.RNK
# Se hace request GET 36 para el indicador VA.PER.RNK
# Se hace request GET 37 para el indicador VA.PER.RNK
# Se hace request GET 38 para el indicador VA.PER.RNK
# Se hace request GET 39 para el indicador VA.PER.RNK
# Se hace request GET 40 para el indicador VA.PER.RNK
# Se hace request GET 41 para el indicador VA.PER.RNK
# Se hace request GET 42 para el indicador VA.PER.RNK
# Se hace request GET 43 para el indicador VA.PER.RNK
# Se hace request GET 44 para el indicador VA.PER.RNK
# Se hace request GET 45 para el indicador VA.PER.RNK
# {'page': 1, 'pages': 45, 'per_page': 50, 'total': 2233, 'sourceid': '2', 'lastupdated': '2024-06-28'}
# Se hace request GET 2 para el indicador VA.PER.RNK.LOWER
# Se hace request GET 3 para el indicador VA.PER.RNK.LOWER
# Se hace request GET 4 para el indicador VA.PER.RNK.LOWER
# Se hace request GET 5 para el indicador VA.PER.RNK.LOWER
# Se hace request GET 6 para el indicador VA.PER.RNK.LOWER
# Se hace request GET 7 para el indicador VA.PER.RNK.LOWER
# Se hace request GET 8 para el indicador VA.PER.RNK.LOWER
# Se hace request GET 9 para el indicador VA.PER.RNK.LOWER
# Se hace request GET 10 para el indicador VA.PER.RNK.LOWER
# Se hace request GET 11 para el indicador VA.PER.RNK.LOWER
# Se hace request GET 12 para el indicador VA.PER.RNK.LOWER
# Se hace request GET 13 para el indicador VA.PER.RNK.LOWER
# Se hace request GET 14 para el indicador VA.PER.RNK.LOWER
# Se hace request GET 15 para el indicador VA.PER.RNK.LOWER
# Se hace request GET 16 para el indicador VA.PER.RNK.LOWER
# Se hace request GET 17 para el indicador VA.PER.RNK.LOWER
# Se hace request GET 18 para el indicador VA.PER.RNK.LOWER
# Se hace request GET 19 para el indicador VA.PER.RNK.LOWER
# Se hace request GET 20 para el indicador VA.PER.RNK.LOWER
# Se hace request GET 21 para el indicador VA.PER.RNK.LOWER
# Se hace request GET 22 para el indicador VA.PER.RNK.LOWER
# Se hace request GET 23 para el indicador VA.PER.RNK.LOWER
# Se hace request GET 24 para el indicador VA.PER.RNK.LOWER
# Se hace request GET 25 para el indicador VA.PER.RNK.LOWER
# Se hace request GET 26 para el indicador VA.PER.RNK.LOWER
# Se hace request GET 27 para el indicador VA.PER.RNK.LOWER
# Se hace request GET 28 para el indicador VA.PER.RNK.LOWER
# Se hace request GET 29 para el indicador VA.PER.RNK.LOWER
# Se hace request GET 30 para el indicador VA.PER.RNK.LOWER
# Se hace request GET 31 para el indicador VA.PER.RNK.LOWER
# Se hace request GET 32 para el indicador VA.PER.RNK.LOWER
# Se hace request GET 33 para el indicador VA.PER.RNK.LOWER
# Se hace request GET 34 para el indicador VA.PER.RNK.LOWER
# Se hace request GET 35 para el indicador VA.PER.RNK.LOWER
# Se hace request GET 36 para el indicador VA.PER.RNK.LOWER
# Se hace request GET 37 para el indicador VA.PER.RNK.LOWER
# Se hace request GET 38 para el indicador VA.PER.RNK.LOWER
# Se hace request GET 39 para el indicador VA.PER.RNK.LOWER
# Se hace request GET 40 para el indicador VA.PER.RNK.LOWER
# Se hace request GET 41 para el indicador VA.PER.RNK.LOWER
# Se hace request GET 42 para el indicador VA.PER.RNK.LOWER
# Se hace request GET 43 para el indicador VA.PER.RNK.LOWER
# Se hace request GET 44 para el indicador VA.PER.RNK.LOWER
# Se hace request GET 45 para el indicador VA.PER.RNK.LOWER
# {'page': 1, 'pages': 45, 'per_page': 50, 'total': 2233, 'sourceid': '2', 'lastupdated': '2024-06-28'}
# Se hace request GET 2 para el indicador VA.PER.RNK.UPPER
# Se hace request GET 3 para el indicador VA.PER.RNK.UPPER
# Se hace request GET 4 para el indicador VA.PER.RNK.UPPER
# Se hace request GET 5 para el indicador VA.PER.RNK.UPPER
# Se hace request GET 6 para el indicador VA.PER.RNK.UPPER
# Se hace request GET 7 para el indicador VA.PER.RNK.UPPER
# Se hace request GET 8 para el indicador VA.PER.RNK.UPPER
# Se hace request GET 9 para el indicador VA.PER.RNK.UPPER
# Se hace request GET 10 para el indicador VA.PER.RNK.UPPER
# Se hace request GET 11 para el indicador VA.PER.RNK.UPPER
# Se hace request GET 12 para el indicador VA.PER.RNK.UPPER
# Se hace request GET 13 para el indicador VA.PER.RNK.UPPER
# Se hace request GET 14 para el indicador VA.PER.RNK.UPPER
# Se hace request GET 15 para el indicador VA.PER.RNK.UPPER
# Se hace request GET 16 para el indicador VA.PER.RNK.UPPER
# Se hace request GET 17 para el indicador VA.PER.RNK.UPPER
# Se hace request GET 18 para el indicador VA.PER.RNK.UPPER
# Se hace request GET 19 para el indicador VA.PER.RNK.UPPER
# Se hace request GET 20 para el indicador VA.PER.RNK.UPPER
# Se hace request GET 21 para el indicador VA.PER.RNK.UPPER
# Se hace request GET 22 para el indicador VA.PER.RNK.UPPER
# Se hace request GET 23 para el indicador VA.PER.RNK.UPPER
# Se hace request GET 24 para el indicador VA.PER.RNK.UPPER
# Se hace request GET 25 para el indicador VA.PER.RNK.UPPER
# Se hace request GET 26 para el indicador VA.PER.RNK.UPPER
# Se hace request GET 27 para el indicador VA.PER.RNK.UPPER
# Se hace request GET 28 para el indicador VA.PER.RNK.UPPER
# Se hace request GET 29 para el indicador VA.PER.RNK.UPPER
# Se hace request GET 30 para el indicador VA.PER.RNK.UPPER
# Se hace request GET 31 para el indicador VA.PER.RNK.UPPER
# Se hace request GET 32 para el indicador VA.PER.RNK.UPPER
# Se hace request GET 33 para el indicador VA.PER.RNK.UPPER
# Se hace request GET 34 para el indicador VA.PER.RNK.UPPER
# Se hace request GET 35 para el indicador VA.PER.RNK.UPPER
# Se hace request GET 36 para el indicador VA.PER.RNK.UPPER
# Se hace request GET 37 para el indicador VA.PER.RNK.UPPER
# Se hace request GET 38 para el indicador VA.PER.RNK.UPPER
# Se hace request GET 39 para el indicador VA.PER.RNK.UPPER
# Se hace request GET 40 para el indicador VA.PER.RNK.UPPER
# Se hace request GET 41 para el indicador VA.PER.RNK.UPPER
# Se hace request GET 42 para el indicador VA.PER.RNK.UPPER
# Se hace request GET 43 para el indicador VA.PER.RNK.UPPER
# Se hace request GET 44 para el indicador VA.PER.RNK.UPPER
# Se hace request GET 45 para el indicador VA.PER.RNK.UPPER
# {'page': 1, 'pages': 45, 'per_page': 50, 'total': 2233, 'sourceid': '2', 'lastupdated': '2024-06-28'}
# Se hace request GET 2 para el indicador VA.STD.ERR
# Se hace request GET 3 para el indicador VA.STD.ERR
# Se hace request GET 4 para el indicador VA.STD.ERR
# Se hace request GET 5 para el indicador VA.STD.ERR
# Se hace request GET 6 para el indicador VA.STD.ERR
# Se hace request GET 7 para el indicador VA.STD.ERR
# Se hace request GET 8 para el indicador VA.STD.ERR
# Se hace request GET 9 para el indicador VA.STD.ERR
# Se hace request GET 10 para el indicador VA.STD.ERR
# Se hace request GET 11 para el indicador VA.STD.ERR
# Se hace request GET 12 para el indicador VA.STD.ERR
# Se hace request GET 13 para el indicador VA.STD.ERR
# Se hace request GET 14 para el indicador VA.STD.ERR
# Se hace request GET 15 para el indicador VA.STD.ERR
# Se hace request GET 16 para el indicador VA.STD.ERR
# Se hace request GET 17 para el indicador VA.STD.ERR
# Se hace request GET 18 para el indicador VA.STD.ERR
# Se hace request GET 19 para el indicador VA.STD.ERR
# Se hace request GET 20 para el indicador VA.STD.ERR
# Se hace request GET 21 para el indicador VA.STD.ERR
# Se hace request GET 22 para el indicador VA.STD.ERR
# Se hace request GET 23 para el indicador VA.STD.ERR
# Se hace request GET 24 para el indicador VA.STD.ERR
# Se hace request GET 25 para el indicador VA.STD.ERR
# Se hace request GET 26 para el indicador VA.STD.ERR
# Se hace request GET 27 para el indicador VA.STD.ERR
# Se hace request GET 28 para el indicador VA.STD.ERR
# Se hace request GET 29 para el indicador VA.STD.ERR
# Se hace request GET 30 para el indicador VA.STD.ERR
# Se hace request GET 31 para el indicador VA.STD.ERR
# Se hace request GET 32 para el indicador VA.STD.ERR
# Se hace request GET 33 para el indicador VA.STD.ERR
# Se hace request GET 34 para el indicador VA.STD.ERR
# Se hace request GET 35 para el indicador VA.STD.ERR
# Se hace request GET 36 para el indicador VA.STD.ERR
# Se hace request GET 37 para el indicador VA.STD.ERR
# Se hace request GET 38 para el indicador VA.STD.ERR
# Se hace request GET 39 para el indicador VA.STD.ERR
# Se hace request GET 40 para el indicador VA.STD.ERR
# Se hace request GET 41 para el indicador VA.STD.ERR
# Se hace request GET 42 para el indicador VA.STD.ERR
# Se hace request GET 43 para el indicador VA.STD.ERR
# Se hace request GET 44 para el indicador VA.STD.ERR
# Se hace request GET 45 para el indicador VA.STD.ERR
